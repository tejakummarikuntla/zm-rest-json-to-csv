# %%
import os
import requests
import logging
from io import StringIO
import urllib.request 
import requests
import json
from pandas.io.json import json_normalize 
from datetime import datetime
from time import time

gplRootEndpoint = 'https://maps.googleapis.com/maps/api/place/textsearch/json?'
gApiToken = ''

txtSearchParms = 'query={query}&pagetoken={pageToken}&key={apiKey}'
restAreaList = ['Adyar', 'Alwerpet', 'Nungambakkam', 'Velachery', 'Guindy']
pageToken = ''

reqRestUrl = gplRootEndpoint + txtSearchParms.format(query = 'restaurants+in+{area}'.format(area = restAreaList[0]),
                                                    pageToken = pageToken,
                                                    apiKey = gApiToken)

# %%
reqRestUrl
# Out:
# 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants+in+Adyar&pagetoken=&key=AIzaSyAVv5ZvaIZ1S4od-VMPmQHc-1kgtL01bOM'

# %%
plApiResponse = requests.get(reqRestUrl).json()

# %%
type(plApiResponse['results'])
# Out:
# list

# %%
plApiResponse['results'][0]
# Out:
# {'formatted_address': 'Villa 77, 1st Main Rd, Gandhi Nagar, Adyar, Chennai, Tamil Nadu 600020, India',
#  'geometry': {'location': {'lat': 13.006781, 'lng': 80.256148},
#   'viewport': {'northeast': {'lat': 13.00806827989272,
#     'lng': 80.25757792989272},
#    'southwest': {'lat': 13.00536862010728, 'lng': 80.25487827010728}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#  'id': '1ef22b491fc76d87904c82a5a60799eb6598956b',
#  'name': 'Bombay Brasserie - Adyar',
#  'opening_hours': {'open_now': True},
#  'photos': [{'height': 2592,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113619420697059120903/photos">Jom Kuriakose</a>'],
#    'photo_reference': 'CmRaAAAAhM7Et_jLO_Ke_1Ag5e5L-GWnd4pxjUD-5j7v3F4LkB9XKzf9HRYDi_WoS5EYDgbw3wtbS_TVQ29k0gZi8IZBCOzsaCVYt8HvyjCidpxMlxTGGRvJjpuPjvzbkRp0k6acEhCBYRQoT3eXtZapop0Tj0zoGhQhdTgJ7jAS5Irq5K6nuvMm-JQKMg',
#    'width': 4608}],
#  'place_id': 'ChIJ0w0p6-tnUjoRGndM_DLHvMM',
# ...

# %%
for area in restAreaList:
    reqRestUrl = gplRootEndpoint + txtSearchParms.format(query = 'restaurants+in+{Inarea}'.format(Inarea = area),
                                                    pageToken = pageToken,
                                                    apiKey = gApiToken)
    plApiResponse = requests.get(reqRestUrl).json()
    
    if 'next_page_token' in plApiResponse:
        pageToken = plApiResponse['next_page_token']

# %%
plApiResponse
# Out:
# 'CvQD6wEAADWdVSDhGyhtuiaL_UjCOE1jpzESriv33zsnPjYMAoPXw4DdAcmIhzGy6A4LP2kIh6XT7dB-zaiTzECFnlBhSA4M4SxE8e3WBM4PD7KdjWkB5CHR47hfblWrEkWjtuAlGcCUeaLwfJe-hxC-9G932L_qIilk5_PdJk3Gr3FeO6-vdvfxwKB7T5SRr7YG5uJYeAUUq7PIwwFWLJSK5qpTC8s6BFW7zjmoS8lX7Hu3VgDdkERJfdZyfaoLZ-xinc4cF
                                                    apiKey = gApiToken)
plApiResponse = requests.get(reqRestUrl).json()

# %%
#plApiResponse['next_page_token'] == None
if 'next_page_token' in plApiResponse:
    print("No true")

# %%
plApiResponse['results'].append(plApiResponse['results'])

# %%
#plApiResponse
chnDf = json_normalize(plApiResponse['results'])
chnDf.head()
# Out:
#                                    formatted_address  geometry.location.lat  \
# 0  Dr Muthu Lakshmi Rd, Shastri Nagar, Adyar, Che...              12.998615
# 1  No: 18, 5th Cross Street, Indira Nagar, Adyar,...              12.996360
# 2  21, Sardar Patel Rd, Nethaji Colony, Kasturba ...              13.006192
# 3  21/2, Northern Arcade, Lattice Bridge Rd, Adya...              12.995726
# 4  17, 5th Ave, Besant Nagar, Chennai, Tamil Nadu...              13.002852
#
#    geometry.location.lng  geometry.viewport.northeast.lat  \
# 0              80.256196                        12.999972
# 1              80.252534                        12.997720
# 2              80.253142                        13.007706
# 3              80.256063                        12.997127
# 4              80.272069                        13.004149
#
#    geometry.viewport.northeast.lng  geometry.viewport.southwest.lat  \
# 0                        80.257494                        12.997273
# ...

# %%
r = json.dumps(plApiResponse)
loaded_R=  json.loads(r)

# %%
ress = plApiResponse['results']

# %%
#plApiResponse
chnDf = json_normalize(plApiResponse['results'])

# %%
len(plApiResponse['results'])
# Out:
# 22

# %%
plApiResponse['results']
# Out:
# [{'formatted_address': 'Dr Muthu Lakshmi Rd, Shastri Nagar, Adyar, Chennai, Tamil Nadu 600020, India',
#   'geometry': {'location': {'lat': 12.9986148, 'lng': 80.2561958},
#    'viewport': {'northeast': {'lat': 12.99997227989272,
#      'lng': 80.25749422989271},
#     'southwest': {'lat': 12.99727262010728, 'lng': 80.25479457010726}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '90b50d42863566cae007f83566fa4d3e157f9600',
#   'name': 'Hotel Topsee',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107403977929816560653/photos">Syed Abrar Hussaini</a>'],
#     'photo_reference': 'CmRaAAAAZBrWtVo1obs2IiNuw056RbwPNLXw3BCiK8TAFS2YPD333NiaV3R8K68s6a-cwpd_JsYMsYI_KIWye_gWHZ0IWjaQQuonns4yY5zcGzlujen8OMLRCxWyo6tgeBlGWDObEhDzkhR4BeU2pHkxWwXphuWVGhR1-jMrj-Rjx8HVOtQKVsJ2KVjUNg',
#     'width': 4608}],
#   'place_id': 'ChIJRWjjG_NnUjoRYUbXNHvoqDM',
# ...

# %%
resss = plApiResponse['results']

# %%
type(ress)
# Out:
# list

# %%
#d = json.loads(str(plApiResponse)[1:-1])

# %%
plApiResponse['results'].append(plApiResponse['results'][0])

# %%
type(plApiResponse['results'])
# Out:
# list

# %%
chnDf = json_normalize(plApiResponse['results'])

# %%
type(plApiResponse['results'][0])
# Out:
# dict

# %%
len(plApiResponse['results'])
# Out:
# 21

# %%
for dic in plApiResponse['results']:
    plApiResponse['results'].append(dic)
